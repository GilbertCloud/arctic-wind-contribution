# %% [markdown]
# # Processing CESM2-LENS PiC & lessmelt data

# %% [markdown]
# ### Set up
# #### Packages

# %%
import numpy as np
import xarray as xr
import pandas as pd
from scipy import stats
import warnings
warnings.simplefilter('ignore', UserWarning)
warnings.filterwarnings('ignore')
import datetime as dt
from datetime import timedelta
from Processing_functions import FixLongitude, FixTime, FixGrid, InterPlevels
xr.set_options(display_expand_data=False);
import dask
from dask_jobqueue import PBSCluster
from dask.distributed import Client
from dask.diagnostics import ProgressBar
import random
import os

# %% [markdown]
# #### Filepaths & name variables

# %%
lessmelt = True

## File name
cesm2piC = 'b.e21.B1850.f09_g17.CMIP6-piControl.001_branch2' if lessmelt else 'b.e21.B1850.f09_g17.CMIP6-piControl.001' 

## Filepaths
path_to_arch = "/glade/campaign/cgd/ppc/cesm2_tuned_albedo/" if lessmelt else "/glade/campaign/collections/cmip/CMIP6/timeseries-cmip6/"
comp = 'ice'
freq = 0 # 0: monthly, 1: daily
var_ind = 2

# Variables
var_list = {'atm': ['TS','FLDS','CLOUD','FLNS','FSNS','FLNT','FSNT','PSL','U','V','T','TREFHT','RESTOM','Z3'],
            'ice': ['aice','hi', 'hs'],
            'ocn': ['MOC']}
var_ext = {0: '', 1: '_d'}
var = var_list[comp][var_ind]+var_ext[freq]

# Extensions
h_ext = {'atm': ['.h0.'],
       'ice': ['.h.','.h1.'],
       'ocn': ['.h.']}
mod_com = {'atm': 'cam',
           'ice': 'cice',
           'ocn': 'pop'}
time_path = {'atm': ['month_1'],
                'ice': ['month_1','day_1'],
                'ocn': ['month_1']}
vert_lev = {'atm': [False,False,True,False,False,False,False,False,True,True,True,False,False,True],
            'ice': [False,False,False],
            'ocn': [False]}

path_to_outdata = '/glade/work/glydia/processed_CESM2_lessmelt_data/' if lessmelt else '/glade/work/glydia/processed_CESM2_LENS_data/'
plot_levels = [300,500,850,925]

# %%
cluster = PBSCluster(cores    = 1,
                     memory   = '25GiB',
                     queue    = 'casper',
                     walltime = '04:00:00',
                     account  = 'UCUB0155',
                     name='piControl_'+var)
cluster.scale(4*9)
client = Client(cluster)

# %%
client
# Out:
# <Client: 'tcp://128.117.208.98:40851' processes=0 threads=0, memory=0 B>

# %%
## Chunking variables
time_ch = 365*2 if freq == 1 else 600
chunks = {
    'atm': {'time': time_ch, 'lat': 96, 'lon': 144, 'lev': -1},
    'ice': {'time': time_ch, 'nj': 192, 'ni': 160},
    'ocn': {'time': time_ch, 'nlat': 64, 'nlon': 96, 'z_t': 5}
}

# %% [markdown]
# ### Load & modify data
# #### Control data

# %%
startyrs = np.arange(811,1162,50)
print(startyrs)
# Out:
# [ 811  861  911  961 1011 1061 1111 1161]

# %%
# %%time
if var != 'RESTOM' and not vert_lev[comp][var_ind]:
    filepath = path_to_arch+cesm2piC+'/'+comp+'/proc/tseries/'
    addon = 'Kayetal22/' if (lessmelt and comp == 'ice') else time_path[comp][freq]+'/'
    filepath = filepath+addon

    if lessmelt:
        filename = cesm2piC+'.'+mod_com[comp]+h_ext[comp][freq]+var+'.*.'+'nc'
        ds = dask.delayed(xr.open_mfdataset)(filepath+filename,chunks=chunks[comp])
    
    num = 0
    for startyr in startyrs:
        yr_range = np.array([str(i).zfill(4) for i in np.arange(startyr,startyr+51)])
        
        endyr = startyr+49
        # start_floor = np.floor_divide(startyr,100)
        # end_floor = np.floor_divide(endyr,100)
        
        # if start_floor == end_floor:
        #     if start_floor == 0:
        #         instart = str(1).zfill(4)
        #         inend = str(99).zfill(4)
        #     elif start_floor == 19:
        #         instart = str(1900).zfill(4)
        #         inend = str(2000).zfill(4)
        #     else:
        #         instart = str(start_floor*100).zfill(4)
        #         inend = str(start_floor*100+99).zfill(4)
        
        #     yr_extn = {'in': ["."+instart+"01-"+inend+"12.", ".05000101-05991231."],
        #                'out': ["."+str(startyr).zfill(4)+"01-"+str(endyr).zfill(4)+"12.", ".05010101-05741231."]}

        #     outpath = path_to_outdata+cesm2piC+h_ext[comp][freq]+var+yr_extn['out'][freq]+'zarr'
        #     if os.path.isdir(outpath):
        #         print(cesm2piC+h_ext[comp][freq]+var+yr_extn['out'][freq]+'zarr exists')
        #         continue
        #     else:
        #         # Open dataset
        #         filename = cesm2piC+'.'+mod_com[comp]+h_ext[comp][freq]+var+yr_extn['in'][freq]+'nc'
        #         print(filepath+filename)
        #         ds = dask.delayed(xr.open_dataset)(filepath+filename,chunks=chunks[comp])
        #         # ds = xr.open_dataset(filepath+filename,chunks=chunks[comp])
        # else:
        #     if start_floor == 0:
        #         instart1 = str(1).zfill(4)
        #         inend1 = str(99).zfill(4)
        #     else:
        #         instart1 = str(start_floor*100).zfill(4)
        #         inend1 = str(start_floor*100+99).zfill(4)
                
        #     if end_floor == 19:
        #         instart2 = str(1900).zfill(4)
        #         inend2 = str(2000).zfill(4)
        #     else:
        #         instart2 = str(end_floor*100).zfill(4)
        #         inend2 = str(end_floor*100+99).zfill(4)
    
        #     yr_extn1 = {'in': ["."+instart1+"01-"+inend1+"12.", ".05000101-05991231."],
        #                'out': ["."+str(startyr).zfill(4)+"01-"+str(endyr).zfill(4)+"12.", ".05010101-05741231."]}
    
        #     yr_extn2 = {'in': ["."+instart2+"01-"+inend2+"12.", ".05000101-05991231."],
        #                'out': ["."+str(startyr).zfill(4)+"01-"+str(endyr).zfill(4)+"12.", ".05010101-05741231."]}
        #     yr_extn = {'out': ["."+str(startyr).zfill(4)+"01-"+str(endyr).zfill(4)+"12.", ".05010101-05741231."]}

        #     # Open dataset
        #     filename1 = cesm2piC+'.'+mod_com[comp]+h_ext[comp][freq]+var+yr_extn1['in'][freq]+'nc'
        #     filename2 = cesm2piC+'.'+mod_com[comp]+h_ext[comp][freq]+var+yr_extn2['in'][freq]+'nc'
        #     print(filepath+filename1)
        #     print(filepath+filename2)
        #     ds = dask.delayed(xr.open_mfdataset)([filepath+filename1, filepath+filename2],chunks=chunks[comp])
        #     # ds = xr.open_mfdataset([filepath+filename1, filepath+filename2],chunks=chunks[comp])

        yr_extn = {'out': ["."+str(startyr).zfill(4)+"01-"+str(endyr).zfill(4)+"12.", ".05010101-05741231."]}
        add_cyclic = False
        dsv = ds[var]
     
        #del ds
        
        processed_list = []
        for i in range(0,len(yr_range)-1):
            # If monthly data
            if freq == 0:
                startyr_sl = yr_range[i]
                endyr_sl = yr_range[i+1]
                ann_slice = dsv.sel(time=slice(startyr_sl+'-02-01',endyr_sl+'-01-17')) #if add_cyclic else dsv.sel(time=slice(startyr+'-02-10',endyr+'-01-17'),lat=slice(0,90))
                print('sliced '+startyr_sl+'-02-01 to '+endyr_sl+'-01-17')
                
                #fixedtime_data = dask.delayed(FixTime)(ann_slice)
                fixedtime_data = FixTime(ann_slice)
                print('   fixed time')
        
                if comp == 'ice':
                    fixedgrid_data = dask.delayed(FixGrid)(fixedtime_data,'gx1v7')
                    processed_list.append(fixedgrid_data)
                    print('   fixed CICE grid')
        
                    #del ann_slice, fixedtime_data, fixedgrid_data
                elif comp == 'ocn':
                    processed_list.append(fixedtime_data)
        
                    #del ann_slice, fixedtime_data
                else:
                    fixedgrid_data = dask.delayed(FixLongitude)(fixedtime_data, add_cyclic)
                    processed_list.append(fixedgrid_data)
                    print('   fixed longitude')
        
                    #del ann_slice, fixedtime_data, fixedgrid_data
                    
                
            # If daily data
            else:
                startyr_sl = yr_range[i]
                endyr_sl = yr_range[i]
                ann_slice = dsv.sel(time=slice(startyr_sl+'-01-01',endyr_sl+'-12-31')) #if add_cyclic else dsv.sel(time=slice(startyr+'-01-01',endyr+'-12-31'), lat=slice(0,90))
                print('sliced '+startyr_sl+'-01-01 to '+endyr_sl+'-12-31')
        
                if comp == 'ice':
                    fixedgrid_data = dask.delayed(FixGrid)(ann_slice,'gx1v7')
                    processed_list.append(fixedgrid_data)
                    print('   fixed CICE grid')
        
                    #del ann_slice, fixedgrid_data
                elif comp == 'ocn':
                    processed_list.append(ann_slice)
        
                    #del ann_slice
                else:
                    fixedgrid_data = dask.delayed(FixLongitude)(ann_slice, add_cyclic)
                    processed_list.append(fixedgrid_data)
                    print('   fixed longitude')
        
                    #del ann_slice, fixedgrid_data
        
        if freq == 0 and not vert_lev[comp][var_ind]:
            processed_comp = dask.compute(*processed_list)
            print('computed list')
            
            processed_out = xr.concat(processed_comp,dim='time').chunk({'time':111})
            print('concatenated data')
            
            processed_out.to_netcdf(path_to_outdata+cesm2piC+h_ext[comp][freq]+var+yr_extn['out'][freq]+'nc', 
                                        format='NETCDF4',encoding={var: {"zlib": True, "complevel": 1}})
            print('wrote data to disk')
    
        num = num+1
# Out:
# sliced 0811-02-01 to 0812-01-17
#    fixed time
#    fixed CICE grid
# sliced 0812-02-01 to 0813-01-17
#    fixed time
#    fixed CICE grid
# sliced 0813-02-01 to 0814-01-17
#    fixed time
#    fixed CICE grid
# sliced 0814-02-01 to 0815-01-17
#    fixed time
#    fixed CICE grid
# sliced 0815-02-01 to 0816-01-17
#    fixed time
#    fixed CICE grid
# sliced 0816-02-01 to 0817-01-17
#    fixed time
#    fixed CICE grid
# sliced 0817-02-01 to 0818-01-17
#    fixed time
#    fixed CICE grid
# sliced 0818-02-01 to 0819-01-17
#    fixed time
#    fixed CICE grid
# sliced 0819-02-01 to 0820-01-17
#    fixed time
#    fixed CICE grid
# sliced 0820-02-01 to 0821-01-17
#    fixed time
#    fixed CICE grid
# sliced 0821-02-01 to 0822-01-17
#    fixed time
#    fixed CICE grid
# sliced 0822-02-01 to 0823-01-17
#    fixed time
#    fixed CICE grid
# sliced 0823-02-01 to 0824-01-17
#    fixed time
#    fixed CICE grid
# sliced 0824-02-01 to 0825-01-17
#    fixed time
#    fixed CICE grid
# sliced 0825-02-01 to 0826-01-17
#    fixed time
#    fixed CICE grid
# sliced 0826-02-01 to 0827-01-17
#    fixed time
#    fixed CICE grid
# sliced 0827-02-01 to 0828-01-17
#    fixed time
#    fixed CICE grid
# sliced 0828-02-01 to 0829-01-17
#    fixed time
#    fixed CICE grid
# sliced 0829-02-01 to 0830-01-17
#    fixed time
#    fixed CICE grid
# sliced 0830-02-01 to 0831-01-17
#    fixed time
#    fixed CICE grid
# sliced 0831-02-01 to 0832-01-17
#    fixed time
#    fixed CICE grid
# sliced 0832-02-01 to 0833-01-17
#    fixed time
#    fixed CICE grid
# sliced 0833-02-01 to 0834-01-17
#    fixed time
#    fixed CICE grid
# sliced 0834-02-01 to 0835-01-17
#    fixed time
#    fixed CICE grid
# sliced 0835-02-01 to 0836-01-17
#    fixed time
#    fixed CICE grid
# sliced 0836-02-01 to 0837-01-17
#    fixed time
#    fixed CICE grid
# sliced 0837-02-01 to 0838-01-17
#    fixed time
#    fixed CICE grid
# sliced 0838-02-01 to 0839-01-17
#    fixed time
#    fixed CICE grid
# sliced 0839-02-01 to 0840-01-17
#    fixed time
#    fixed CICE grid
# sliced 0840-02-01 to 0841-01-17
#    fixed time
#    fixed CICE grid
# sliced 0841-02-01 to 0842-01-17
#    fixed time
#    fixed CICE grid
# sliced 0842-02-01 to 0843-01-17
#    fixed time
#    fixed CICE grid
# sliced 0843-02-01 to 0844-01-17
#    fixed time
#    fixed CICE grid
# sliced 0844-02-01 to 0845-01-17
#    fixed time
#    fixed CICE grid
# sliced 0845-02-01 to 0846-01-17
#    fixed time
#    fixed CICE grid
# sliced 0846-02-01 to 0847-01-17
#    fixed time
#    fixed CICE grid
# sliced 0847-02-01 to 0848-01-17
#    fixed time
#    fixed CICE grid
# sliced 0848-02-01 to 0849-01-17
#    fixed time
#    fixed CICE grid
# sliced 0849-02-01 to 0850-01-17
#    fixed time
#    fixed CICE grid
# sliced 0850-02-01 to 0851-01-17
#    fixed time
#    fixed CICE grid
# sliced 0851-02-01 to 0852-01-17
#    fixed time
#    fixed CICE grid
# sliced 0852-02-01 to 0853-01-17
#    fixed time
#    fixed CICE grid
# sliced 0853-02-01 to 0854-01-17
#    fixed time
#    fixed CICE grid
# sliced 0854-02-01 to 0855-01-17
#    fixed time
#    fixed CICE grid
# sliced 0855-02-01 to 0856-01-17
#    fixed time
#    fixed CICE grid
# sliced 0856-02-01 to 0857-01-17
#    fixed time
#    fixed CICE grid
# sliced 0857-02-01 to 0858-01-17
#    fixed time
#    fixed CICE grid
# sliced 0858-02-01 to 0859-01-17
#    fixed time
#    fixed CICE grid
# sliced 0859-02-01 to 0860-01-17
#    fixed time
#    fixed CICE grid
# sliced 0860-02-01 to 0861-01-17
#    fixed time
#    fixed CICE grid
# computed list
# concatenated data
# wrote data to disk
# sliced 0861-02-01 to 0862-01-17
#    fixed time
#    fixed CICE grid
# sliced 0862-02-01 to 0863-01-17
#    fixed time
#    fixed CICE grid
# sliced 0863-02-01 to 0864-01-17
#    fixed time
#    fixed CICE grid
# sliced 0864-02-01 to 0865-01-17
#    fixed time
#    fixed CICE grid
# sliced 0865-02-01 to 0866-01-17
#    fixed time
#    fixed CICE grid
# sliced 0866-02-01 to 0867-01-17
#    fixed time
#    fixed CICE grid
# sliced 0867-02-01 to 0868-01-17
#    fixed time
#    fixed CICE grid
# sliced 0868-02-01 to 0869-01-17
#    fixed time
#    fixed CICE grid
# sliced 0869-02-01 to 0870-01-17
#    fixed time
#    fixed CICE grid
# sliced 0870-02-01 to 0871-01-17
#    fixed time
#    fixed CICE grid
# sliced 0871-02-01 to 0872-01-17
#    fixed time
#    fixed CICE grid
# sliced 0872-02-01 to 0873-01-17
#    fixed time
#    fixed CICE grid
# sliced 0873-02-01 to 0874-01-17
#    fixed time
#    fixed CICE grid
# sliced 0874-02-01 to 0875-01-17
#    fixed time
#    fixed CICE grid
# sliced 0875-02-01 to 0876-01-17
#    fixed time
#    fixed CICE grid
# sliced 0876-02-01 to 0877-01-17
#    fixed time
#    fixed CICE grid
# sliced 0877-02-01 to 0878-01-17
#    fixed time
#    fixed CICE grid
# sliced 0878-02-01 to 0879-01-17
#    fixed time
#    fixed CICE grid
# sliced 0879-02-01 to 0880-01-17
#    fixed time
#    fixed CICE grid
# sliced 0880-02-01 to 0881-01-17
#    fixed time
#    fixed CICE grid
# sliced 0881-02-01 to 0882-01-17
#    fixed time
#    fixed CICE grid
# sliced 0882-02-01 to 0883-01-17
#    fixed time
#    fixed CICE grid
# sliced 0883-02-01 to 0884-01-17
#    fixed time
#    fixed CICE grid
# sliced 0884-02-01 to 0885-01-17
#    fixed time
#    fixed CICE grid
# sliced 0885-02-01 to 0886-01-17
#    fixed time
#    fixed CICE grid
# sliced 0886-02-01 to 0887-01-17
#    fixed time
#    fixed CICE grid
# sliced 0887-02-01 to 0888-01-17
#    fixed time
#    fixed CICE grid
# sliced 0888-02-01 to 0889-01-17
#    fixed time
#    fixed CICE grid
# sliced 0889-02-01 to 0890-01-17
#    fixed time
#    fixed CICE grid
# sliced 0890-02-01 to 0891-01-17
#    fixed time
#    fixed CICE grid
# sliced 0891-02-01 to 0892-01-17
#    fixed time
#    fixed CICE grid
# sliced 0892-02-01 to 0893-01-17
#    fixed time
#    fixed CICE grid
# sliced 0893-02-01 to 0894-01-17
#    fixed time
#    fixed CICE grid
# sliced 0894-02-01 to 0895-01-17
#    fixed time
#    fixed CICE grid
# sliced 0895-02-01 to 0896-01-17
#    fixed time
#    fixed CICE grid
# sliced 0896-02-01 to 0897-01-17
#    fixed time
#    fixed CICE grid
# sliced 0897-02-01 to 0898-01-17
#    fixed time
#    fixed CICE grid
# sliced 0898-02-01 to 0899-01-17
#    fixed time
#    fixed CICE grid
# sliced 0899-02-01 to 0900-01-17
#    fixed time
#    fixed CICE grid
# sliced 0900-02-01 to 0901-01-17
#    fixed time
#    fixed CICE grid
# sliced 0901-02-01 to 0902-01-17
#    fixed time
#    fixed CICE grid
# sliced 0902-02-01 to 0903-01-17
#    fixed time
#    fixed CICE grid
# sliced 0903-02-01 to 0904-01-17
#    fixed time
#    fixed CICE grid
# sliced 0904-02-01 to 0905-01-17
#    fixed time
#    fixed CICE grid
# sliced 0905-02-01 to 0906-01-17
#    fixed time
#    fixed CICE grid
# sliced 0906-02-01 to 0907-01-17
#    fixed time
#    fixed CICE grid
# sliced 0907-02-01 to 0908-01-17
#    fixed time
#    fixed CICE grid
# sliced 0908-02-01 to 0909-01-17
#    fixed time
#    fixed CICE grid
# sliced 0909-02-01 to 0910-01-17
#    fixed time
#    fixed CICE grid
# sliced 0910-02-01 to 0911-01-17
#    fixed time
#    fixed CICE grid
# computed list
# concatenated data
# wrote data to disk
# sliced 0911-02-01 to 0912-01-17
#    fixed time
#    fixed CICE grid
# sliced 0912-02-01 to 0913-01-17
#    fixed time
#    fixed CICE grid
# sliced 0913-02-01 to 0914-01-17
#    fixed time
#    fixed CICE grid
# sliced 0914-02-01 to 0915-01-17
#    fixed time
#    fixed CICE grid
# sliced 0915-02-01 to 0916-01-17
#    fixed time
#    fixed CICE grid
# sliced 0916-02-01 to 0917-01-17
#    fixed time
#    fixed CICE grid
# sliced 0917-02-01 to 0918-01-17
#    fixed time
#    fixed CICE grid
# sliced 0918-02-01 to 0919-01-17
#    fixed time
#    fixed CICE grid
# sliced 0919-02-01 to 0920-01-17
#    fixed time
#    fixed CICE grid
# sliced 0920-02-01 to 0921-01-17
#    fixed time
#    fixed CICE grid
# sliced 0921-02-01 to 0922-01-17
#    fixed time
#    fixed CICE grid
# sliced 0922-02-01 to 0923-01-17
#    fixed time
#    fixed CICE grid
# sliced 0923-02-01 to 0924-01-17
#    fixed time
#    fixed CICE grid
# sliced 0924-02-01 to 0925-01-17
#    fixed time
#    fixed CICE grid
# sliced 0925-02-01 to 0926-01-17
#    fixed time
#    fixed CICE grid
# sliced 0926-02-01 to 0927-01-17
#    fixed time
#    fixed CICE grid
# sliced 0927-02-01 to 0928-01-17
#    fixed time
#    fixed CICE grid
# sliced 0928-02-01 to 0929-01-17
#    fixed time
#    fixed CICE grid
# sliced 0929-02-01 to 0930-01-17
#    fixed time
#    fixed CICE grid
# sliced 0930-02-01 to 0931-01-17
#    fixed time
#    fixed CICE grid
# sliced 0931-02-01 to 0932-01-17
#    fixed time
#    fixed CICE grid
# sliced 0932-02-01 to 0933-01-17
#    fixed time
#    fixed CICE grid
# sliced 0933-02-01 to 0934-01-17
#    fixed time
#    fixed CICE grid
# sliced 0934-02-01 to 0935-01-17
#    fixed time
#    fixed CICE grid
# sliced 0935-02-01 to 0936-01-17
#    fixed time
#    fixed CICE grid
# sliced 0936-02-01 to 0937-01-17
#    fixed time
#    fixed CICE grid
# sliced 0937-02-01 to 0938-01-17
#    fixed time
#    fixed CICE grid
# sliced 0938-02-01 to 0939-01-17
#    fixed time
#    fixed CICE grid
# sliced 0939-02-01 to 0940-01-17
#    fixed time
#    fixed CICE grid
# sliced 0940-02-01 to 0941-01-17
#    fixed time
#    fixed CICE grid
# sliced 0941-02-01 to 0942-01-17
#    fixed time
#    fixed CICE grid
# sliced 0942-02-01 to 0943-01-17
#    fixed time
#    fixed CICE grid
# sliced 0943-02-01 to 0944-01-17
#    fixed time
#    fixed CICE grid
# sliced 0944-02-01 to 0945-01-17
#    fixed time
#    fixed CICE grid
# sliced 0945-02-01 to 0946-01-17
#    fixed time
#    fixed CICE grid
# sliced 0946-02-01 to 0947-01-17
#    fixed time
#    fixed CICE grid
# sliced 0947-02-01 to 0948-01-17
#    fixed time
#    fixed CICE grid
# sliced 0948-02-01 to 0949-01-17
#    fixed time
#    fixed CICE grid
# sliced 0949-02-01 to 0950-01-17
#    fixed time
#    fixed CICE grid
# sliced 0950-02-01 to 0951-01-17
#    fixed time
#    fixed CICE grid
# sliced 0951-02-01 to 0952-01-17
#    fixed time
#    fixed CICE grid
# sliced 0952-02-01 to 0953-01-17
#    fixed time
#    fixed CICE grid
# sliced 0953-02-01 to 0954-01-17
#    fixed time
#    fixed CICE grid
# sliced 0954-02-01 to 0955-01-17
#    fixed time
#    fixed CICE grid
# sliced 0955-02-01 to 0956-01-17
#    fixed time
#    fixed CICE grid
# sliced 0956-02-01 to 0957-01-17
#    fixed time
#    fixed CICE grid
# sliced 0957-02-01 to 0958-01-17
#    fixed time
#    fixed CICE grid
# sliced 0958-02-01 to 0959-01-17
#    fixed time
#    fixed CICE grid
# sliced 0959-02-01 to 0960-01-17
#    fixed time
#    fixed CICE grid
# sliced 0960-02-01 to 0961-01-17
#    fixed time
#    fixed CICE grid
# computed list
# concatenated data
# wrote data to disk
# sliced 0961-02-01 to 0962-01-17
#    fixed time
#    fixed CICE grid
# sliced 0962-02-01 to 0963-01-17
#    fixed time
#    fixed CICE grid
# sliced 0963-02-01 to 0964-01-17
#    fixed time
#    fixed CICE grid
# sliced 0964-02-01 to 0965-01-17
#    fixed time
#    fixed CICE grid
# sliced 0965-02-01 to 0966-01-17
#    fixed time
#    fixed CICE grid
# sliced 0966-02-01 to 0967-01-17
#    fixed time
#    fixed CICE grid
# sliced 0967-02-01 to 0968-01-17
#    fixed time
#    fixed CICE grid
# sliced 0968-02-01 to 0969-01-17
#    fixed time
#    fixed CICE grid
# sliced 0969-02-01 to 0970-01-17
#    fixed time
#    fixed CICE grid
# sliced 0970-02-01 to 0971-01-17
#    fixed time
#    fixed CICE grid
# sliced 0971-02-01 to 0972-01-17
#    fixed time
#    fixed CICE grid
# sliced 0972-02-01 to 0973-01-17
#    fixed time
#    fixed CICE grid
# sliced 0973-02-01 to 0974-01-17
#    fixed time
#    fixed CICE grid
# sliced 0974-02-01 to 0975-01-17
#    fixed time
#    fixed CICE grid
# sliced 0975-02-01 to 0976-01-17
#    fixed time
#    fixed CICE grid
# sliced 0976-02-01 to 0977-01-17
#    fixed time
#    fixed CICE grid
# sliced 0977-02-01 to 0978-01-17
#    fixed time
#    fixed CICE grid
# sliced 0978-02-01 to 0979-01-17
#    fixed time
#    fixed CICE grid
# sliced 0979-02-01 to 0980-01-17
#    fixed time
#    fixed CICE grid
# sliced 0980-02-01 to 0981-01-17
#    fixed time
#    fixed CICE grid
# sliced 0981-02-01 to 0982-01-17
#    fixed time
#    fixed CICE grid
# sliced 0982-02-01 to 0983-01-17
#    fixed time
#    fixed CICE grid
# sliced 0983-02-01 to 0984-01-17
#    fixed time
#    fixed CICE grid
# sliced 0984-02-01 to 0985-01-17
#    fixed time
#    fixed CICE grid
# sliced 0985-02-01 to 0986-01-17
#    fixed time
#    fixed CICE grid
# sliced 0986-02-01 to 0987-01-17
#    fixed time
#    fixed CICE grid
# sliced 0987-02-01 to 0988-01-17
#    fixed time
#    fixed CICE grid
# sliced 0988-02-01 to 0989-01-17
#    fixed time
#    fixed CICE grid
# sliced 0989-02-01 to 0990-01-17
#    fixed time
#    fixed CICE grid
# sliced 0990-02-01 to 0991-01-17
#    fixed time
#    fixed CICE grid
# sliced 0991-02-01 to 0992-01-17
#    fixed time
#    fixed CICE grid
# sliced 0992-02-01 to 0993-01-17
#    fixed time
#    fixed CICE grid
# sliced 0993-02-01 to 0994-01-17
#    fixed time
#    fixed CICE grid
# sliced 0994-02-01 to 0995-01-17
#    fixed time
#    fixed CICE grid
# sliced 0995-02-01 to 0996-01-17
#    fixed time
#    fixed CICE grid
# sliced 0996-02-01 to 0997-01-17
#    fixed time
#    fixed CICE grid
# sliced 0997-02-01 to 0998-01-17
#    fixed time
#    fixed CICE grid
# sliced 0998-02-01 to 0999-01-17
#    fixed time
#    fixed CICE grid
# sliced 0999-02-01 to 1000-01-17
#    fixed time
#    fixed CICE grid
# sliced 1000-02-01 to 1001-01-17
#    fixed time
#    fixed CICE grid
# sliced 1001-02-01 to 1002-01-17
#    fixed time
#    fixed CICE grid
# sliced 1002-02-01 to 1003-01-17
#    fixed time
#    fixed CICE grid
# sliced 1003-02-01 to 1004-01-17
#    fixed time
#    fixed CICE grid
# sliced 1004-02-01 to 1005-01-17
#    fixed time
#    fixed CICE grid
# sliced 1005-02-01 to 1006-01-17
#    fixed time
#    fixed CICE grid
# sliced 1006-02-01 to 1007-01-17
#    fixed time
#    fixed CICE grid
# sliced 1007-02-01 to 1008-01-17
#    fixed time
#    fixed CICE grid
# sliced 1008-02-01 to 1009-01-17
#    fixed time
#    fixed CICE grid
# sliced 1009-02-01 to 1010-01-17
#    fixed time
#    fixed CICE grid
# sliced 1010-02-01 to 1011-01-17
#    fixed time
#    fixed CICE grid
# computed list
# concatenated data
# wrote data to disk
# sliced 1011-02-01 to 1012-01-17
#    fixed time
#    fixed CICE grid
# sliced 1012-02-01 to 1013-01-17
#    fixed time
#    fixed CICE grid
# sliced 1013-02-01 to 1014-01-17
#    fixed time
#    fixed CICE grid
# sliced 1014-02-01 to 1015-01-17
#    fixed time
#    fixed CICE grid
# sliced 1015-02-01 to 1016-01-17
#    fixed time
#    fixed CICE grid
# sliced 1016-02-01 to 1017-01-17
#    fixed time
#    fixed CICE grid
# sliced 1017-02-01 to 1018-01-17
#    fixed time
#    fixed CICE grid
# sliced 1018-02-01 to 1019-01-17
#    fixed time
#    fixed CICE grid
# sliced 1019-02-01 to 1020-01-17
#    fixed time
#    fixed CICE grid
# sliced 1020-02-01 to 1021-01-17
#    fixed time
#    fixed CICE grid
# sliced 1021-02-01 to 1022-01-17
#    fixed time
#    fixed CICE grid
# sliced 1022-02-01 to 1023-01-17
#    fixed time
#    fixed CICE grid
# sliced 1023-02-01 to 1024-01-17
#    fixed time
#    fixed CICE grid
# sliced 1024-02-01 to 1025-01-17
#    fixed time
#    fixed CICE grid
# sliced 1025-02-01 to 1026-01-17
#    fixed time
#    fixed CICE grid
# sliced 1026-02-01 to 1027-01-17
#    fixed time
#    fixed CICE grid
# sliced 1027-02-01 to 1028-01-17
#    fixed time
#    fixed CICE grid
# sliced 1028-02-01 to 1029-01-17
#    fixed time
#    fixed CICE grid
# sliced 1029-02-01 to 1030-01-17
#    fixed time
#    fixed CICE grid
# sliced 1030-02-01 to 1031-01-17
#    fixed time
#    fixed CICE grid
# sliced 1031-02-01 to 1032-01-17
#    fixed time
#    fixed CICE grid
# sliced 1032-02-01 to 1033-01-17
#    fixed time
#    fixed CICE grid
# sliced 1033-02-01 to 1034-01-17
#    fixed time
#    fixed CICE grid
# sliced 1034-02-01 to 1035-01-17
#    fixed time
#    fixed CICE grid
# sliced 1035-02-01 to 1036-01-17
#    fixed time
#    fixed CICE grid
# sliced 1036-02-01 to 1037-01-17
#    fixed time
#    fixed CICE grid
# sliced 1037-02-01 to 1038-01-17
#    fixed time
#    fixed CICE grid
# sliced 1038-02-01 to 1039-01-17
#    fixed time
#    fixed CICE grid
# sliced 1039-02-01 to 1040-01-17
#    fixed time
#    fixed CICE grid
# sliced 1040-02-01 to 1041-01-17
#    fixed time
#    fixed CICE grid
# sliced 1041-02-01 to 1042-01-17
#    fixed time
#    fixed CICE grid
# sliced 1042-02-01 to 1043-01-17
#    fixed time
#    fixed CICE grid
# sliced 1043-02-01 to 1044-01-17
#    fixed time
#    fixed CICE grid
# sliced 1044-02-01 to 1045-01-17
#    fixed time
#    fixed CICE grid
# sliced 1045-02-01 to 1046-01-17
#    fixed time
#    fixed CICE grid
# sliced 1046-02-01 to 1047-01-17
#    fixed time
#    fixed CICE grid
# sliced 1047-02-01 to 1048-01-17
#    fixed time
#    fixed CICE grid
# sliced 1048-02-01 to 1049-01-17
#    fixed time
#    fixed CICE grid
# sliced 1049-02-01 to 1050-01-17
#    fixed time
#    fixed CICE grid
# sliced 1050-02-01 to 1051-01-17
#    fixed time
#    fixed CICE grid
# sliced 1051-02-01 to 1052-01-17
#    fixed time
#    fixed CICE grid
# sliced 1052-02-01 to 1053-01-17
#    fixed time
#    fixed CICE grid
# sliced 1053-02-01 to 1054-01-17
#    fixed time
#    fixed CICE grid
# sliced 1054-02-01 to 1055-01-17
#    fixed time
#    fixed CICE grid
# sliced 1055-02-01 to 1056-01-17
#    fixed time
#    fixed CICE grid
# sliced 1056-02-01 to 1057-01-17
#    fixed time
#    fixed CICE grid
# sliced 1057-02-01 to 1058-01-17
#    fixed time
#    fixed CICE grid
# sliced 1058-02-01 to 1059-01-17
#    fixed time
#    fixed CICE grid
# sliced 1059-02-01 to 1060-01-17
#    fixed time
#    fixed CICE grid
# sliced 1060-02-01 to 1061-01-17
#    fixed time
#    fixed CICE grid
# computed list
# concatenated data
# wrote data to disk
# sliced 1061-02-01 to 1062-01-17
#    fixed time
#    fixed CICE grid
# sliced 1062-02-01 to 1063-01-17
#    fixed time
#    fixed CICE grid
# sliced 1063-02-01 to 1064-01-17
#    fixed time
#    fixed CICE grid
# sliced 1064-02-01 to 1065-01-17
#    fixed time
#    fixed CICE grid
# sliced 1065-02-01 to 1066-01-17
#    fixed time
#    fixed CICE grid
# sliced 1066-02-01 to 1067-01-17
#    fixed time
#    fixed CICE grid
# sliced 1067-02-01 to 1068-01-17
#    fixed time
#    fixed CICE grid
# sliced 1068-02-01 to 1069-01-17
#    fixed time
#    fixed CICE grid
# sliced 1069-02-01 to 1070-01-17
#    fixed time
#    fixed CICE grid
# sliced 1070-02-01 to 1071-01-17
#    fixed time
#    fixed CICE grid
# sliced 1071-02-01 to 1072-01-17
#    fixed time
#    fixed CICE grid
# sliced 1072-02-01 to 1073-01-17
#    fixed time
#    fixed CICE grid
# sliced 1073-02-01 to 1074-01-17
#    fixed time
#    fixed CICE grid
# sliced 1074-02-01 to 1075-01-17
#    fixed time
#    fixed CICE grid
# sliced 1075-02-01 to 1076-01-17
#    fixed time
#    fixed CICE grid
# sliced 1076-02-01 to 1077-01-17
#    fixed time
#    fixed CICE grid
# sliced 1077-02-01 to 1078-01-17
#    fixed time
#    fixed CICE grid
# sliced 1078-02-01 to 1079-01-17
#    fixed time
#    fixed CICE grid
# sliced 1079-02-01 to 1080-01-17
#    fixed time
#    fixed CICE grid
# sliced 1080-02-01 to 1081-01-17
#    fixed time
#    fixed CICE grid
# sliced 1081-02-01 to 1082-01-17
#    fixed time
#    fixed CICE grid
# sliced 1082-02-01 to 1083-01-17
#    fixed time
#    fixed CICE grid
# sliced 1083-02-01 to 1084-01-17
#    fixed time
#    fixed CICE grid
# sliced 1084-02-01 to 1085-01-17
#    fixed time
#    fixed CICE grid
# sliced 1085-02-01 to 1086-01-17
#    fixed time
#    fixed CICE grid
# sliced 1086-02-01 to 1087-01-17
#    fixed time
#    fixed CICE grid
# sliced 1087-02-01 to 1088-01-17
#    fixed time
#    fixed CICE grid
# sliced 1088-02-01 to 1089-01-17
#    fixed time
#    fixed CICE grid
# sliced 1089-02-01 to 1090-01-17
#    fixed time
#    fixed CICE grid
# sliced 1090-02-01 to 1091-01-17
#    fixed time
#    fixed CICE grid
# sliced 1091-02-01 to 1092-01-17
#    fixed time
#    fixed CICE grid
# sliced 1092-02-01 to 1093-01-17
#    fixed time
#    fixed CICE grid
# sliced 1093-02-01 to 1094-01-17
#    fixed time
#    fixed CICE grid
# sliced 1094-02-01 to 1095-01-17
#    fixed time
#    fixed CICE grid
# sliced 1095-02-01 to 1096-01-17
#    fixed time
#    fixed CICE grid
# sliced 1096-02-01 to 1097-01-17
#    fixed time
#    fixed CICE grid
# sliced 1097-02-01 to 1098-01-17
#    fixed time
#    fixed CICE grid
# sliced 1098-02-01 to 1099-01-17
#    fixed time
#    fixed CICE grid
# sliced 1099-02-01 to 1100-01-17
#    fixed time
#    fixed CICE grid
# sliced 1100-02-01 to 1101-01-17
#    fixed time
#    fixed CICE grid
# sliced 1101-02-01 to 1102-01-17
#    fixed time
#    fixed CICE grid
# sliced 1102-02-01 to 1103-01-17
#    fixed time
#    fixed CICE grid
# sliced 1103-02-01 to 1104-01-17
#    fixed time
#    fixed CICE grid
# sliced 1104-02-01 to 1105-01-17
#    fixed time
#    fixed CICE grid
# sliced 1105-02-01 to 1106-01-17
#    fixed time
#    fixed CICE grid
# sliced 1106-02-01 to 1107-01-17
#    fixed time
#    fixed CICE grid
# sliced 1107-02-01 to 1108-01-17
#    fixed time
#    fixed CICE grid
# sliced 1108-02-01 to 1109-01-17
#    fixed time
#    fixed CICE grid
# sliced 1109-02-01 to 1110-01-17
#    fixed time
#    fixed CICE grid
# sliced 1110-02-01 to 1111-01-17
#    fixed time
#    fixed CICE grid
# computed list
# concatenated data
# wrote data to disk
# sliced 1111-02-01 to 1112-01-17
#    fixed time
#    fixed CICE grid
# sliced 1112-02-01 to 1113-01-17
#    fixed time
#    fixed CICE grid
# sliced 1113-02-01 to 1114-01-17
#    fixed time
#    fixed CICE grid
# sliced 1114-02-01 to 1115-01-17
#    fixed time
#    fixed CICE grid
# sliced 1115-02-01 to 1116-01-17
#    fixed time
#    fixed CICE grid
# sliced 1116-02-01 to 1117-01-17
#    fixed time
#    fixed CICE grid
# sliced 1117-02-01 to 1118-01-17
#    fixed time
#    fixed CICE grid
# sliced 1118-02-01 to 1119-01-17
#    fixed time
#    fixed CICE grid
# sliced 1119-02-01 to 1120-01-17
#    fixed time
#    fixed CICE grid
# sliced 1120-02-01 to 1121-01-17
#    fixed time
#    fixed CICE grid
# sliced 1121-02-01 to 1122-01-17
#    fixed time
#    fixed CICE grid
# sliced 1122-02-01 to 1123-01-17
#    fixed time
#    fixed CICE grid
# sliced 1123-02-01 to 1124-01-17
#    fixed time
#    fixed CICE grid
# sliced 1124-02-01 to 1125-01-17
#    fixed time
#    fixed CICE grid
# sliced 1125-02-01 to 1126-01-17
#    fixed time
#    fixed CICE grid
# sliced 1126-02-01 to 1127-01-17
#    fixed time
#    fixed CICE grid
# sliced 1127-02-01 to 1128-01-17
#    fixed time
#    fixed CICE grid
# sliced 1128-02-01 to 1129-01-17
#    fixed time
#    fixed CICE grid
# sliced 1129-02-01 to 1130-01-17
#    fixed time
#    fixed CICE grid
# sliced 1130-02-01 to 1131-01-17
#    fixed time
#    fixed CICE grid
# sliced 1131-02-01 to 1132-01-17
#    fixed time
#    fixed CICE grid
# sliced 1132-02-01 to 1133-01-17
#    fixed time
#    fixed CICE grid
# sliced 1133-02-01 to 1134-01-17
#    fixed time
#    fixed CICE grid
# sliced 1134-02-01 to 1135-01-17
#    fixed time
#    fixed CICE grid
# sliced 1135-02-01 to 1136-01-17
#    fixed time
#    fixed CICE grid
# sliced 1136-02-01 to 1137-01-17
#    fixed time
#    fixed CICE grid
# sliced 1137-02-01 to 1138-01-17
#    fixed time
#    fixed CICE grid
# sliced 1138-02-01 to 1139-01-17
#    fixed time
#    fixed CICE grid
# sliced 1139-02-01 to 1140-01-17
#    fixed time
#    fixed CICE grid
# sliced 1140-02-01 to 1141-01-17
#    fixed time
#    fixed CICE grid
# sliced 1141-02-01 to 1142-01-17
#    fixed time
#    fixed CICE grid
# sliced 1142-02-01 to 1143-01-17
#    fixed time
#    fixed CICE grid
# sliced 1143-02-01 to 1144-01-17
#    fixed time
#    fixed CICE grid
# sliced 1144-02-01 to 1145-01-17
#    fixed time
#    fixed CICE grid
# sliced 1145-02-01 to 1146-01-17
#    fixed time
#    fixed CICE grid
# sliced 1146-02-01 to 1147-01-17
#    fixed time
#    fixed CICE grid
# sliced 1147-02-01 to 1148-01-17
#    fixed time
#    fixed CICE grid
# sliced 1148-02-01 to 1149-01-17
#    fixed time
#    fixed CICE grid
# sliced 1149-02-01 to 1150-01-17
#    fixed time
#    fixed CICE grid
# sliced 1150-02-01 to 1151-01-17
#    fixed time
#    fixed CICE grid
# sliced 1151-02-01 to 1152-01-17
#    fixed time
#    fixed CICE grid
# sliced 1152-02-01 to 1153-01-17
#    fixed time
#    fixed CICE grid
# sliced 1153-02-01 to 1154-01-17
#    fixed time
#    fixed CICE grid
# sliced 1154-02-01 to 1155-01-17
#    fixed time
#    fixed CICE grid
# sliced 1155-02-01 to 1156-01-17
#    fixed time
#    fixed CICE grid
# sliced 1156-02-01 to 1157-01-17
#    fixed time
#    fixed CICE grid
# sliced 1157-02-01 to 1158-01-17
#    fixed time
#    fixed CICE grid
# sliced 1158-02-01 to 1159-01-17
#    fixed time
#    fixed CICE grid
# sliced 1159-02-01 to 1160-01-17
#    fixed time
#    fixed CICE grid
# sliced 1160-02-01 to 1161-01-17
#    fixed time
#    fixed CICE grid
# computed list
# concatenated data
# wrote data to disk
# sliced 1161-02-01 to 1162-01-17
#    fixed time
#    fixed CICE grid
# sliced 1162-02-01 to 1163-01-17
#    fixed time
#    fixed CICE grid
# sliced 1163-02-01 to 1164-01-17
#    fixed time
#    fixed CICE grid
# sliced 1164-02-01 to 1165-01-17
#    fixed time
#    fixed CICE grid
# sliced 1165-02-01 to 1166-01-17
#    fixed time
#    fixed CICE grid
# sliced 1166-02-01 to 1167-01-17
#    fixed time
#    fixed CICE grid
# sliced 1167-02-01 to 1168-01-17
#    fixed time
#    fixed CICE grid
# sliced 1168-02-01 to 1169-01-17
#    fixed time
#    fixed CICE grid
# sliced 1169-02-01 to 1170-01-17
#    fixed time
#    fixed CICE grid
# sliced 1170-02-01 to 1171-01-17
#    fixed time
#    fixed CICE grid
# sliced 1171-02-01 to 1172-01-17
#    fixed time
#    fixed CICE grid
# sliced 1172-02-01 to 1173-01-17
#    fixed time
#    fixed CICE grid
# sliced 1173-02-01 to 1174-01-17
#    fixed time
#    fixed CICE grid
# sliced 1174-02-01 to 1175-01-17
#    fixed time
#    fixed CICE grid
# sliced 1175-02-01 to 1176-01-17
#    fixed time
#    fixed CICE grid
# sliced 1176-02-01 to 1177-01-17
#    fixed time
#    fixed CICE grid
# sliced 1177-02-01 to 1178-01-17
#    fixed time
#    fixed CICE grid
# sliced 1178-02-01 to 1179-01-17
#    fixed time
#    fixed CICE grid
# sliced 1179-02-01 to 1180-01-17
#    fixed time
#    fixed CICE grid
# sliced 1180-02-01 to 1181-01-17
#    fixed time
#    fixed CICE grid
# sliced 1181-02-01 to 1182-01-17
#    fixed time
#    fixed CICE grid
# sliced 1182-02-01 to 1183-01-17
#    fixed time
#    fixed CICE grid
# sliced 1183-02-01 to 1184-01-17
#    fixed time
#    fixed CICE grid
# sliced 1184-02-01 to 1185-01-17
#    fixed time
#    fixed CICE grid
# sliced 1185-02-01 to 1186-01-17
#    fixed time
#    fixed CICE grid
# sliced 1186-02-01 to 1187-01-17
#    fixed time
#    fixed CICE grid
# sliced 1187-02-01 to 1188-01-17
#    fixed time
#    fixed CICE grid
# sliced 1188-02-01 to 1189-01-17
#    fixed time
#    fixed CICE grid
# sliced 1189-02-01 to 1190-01-17
#    fixed time
#    fixed CICE grid
# sliced 1190-02-01 to 1191-01-17
#    fixed time
#    fixed CICE grid
# sliced 1191-02-01 to 1192-01-17
#    fixed time
#    fixed CICE grid
# sliced 1192-02-01 to 1193-01-17
#    fixed time
#    fixed CICE grid
# sliced 1193-02-01 to 1194-01-17
#    fixed time
#    fixed CICE grid
# sliced 1194-02-01 to 1195-01-17
#    fixed time
#    fixed CICE grid
# sliced 1195-02-01 to 1196-01-17
#    fixed time
#    fixed CICE grid
# sliced 1196-02-01 to 1197-01-17
#    fixed time
#    fixed CICE grid
# sliced 1197-02-01 to 1198-01-17
#    fixed time
#    fixed CICE grid
# sliced 1198-02-01 to 1199-01-17
#    fixed time
#    fixed CICE grid
# sliced 1199-02-01 to 1200-01-17
#    fixed time
#    fixed CICE grid
# sliced 1200-02-01 to 1201-01-17
#    fixed time
#    fixed CICE grid
# sliced 1201-02-01 to 1202-01-17
#    fixed time
#    fixed CICE grid
# sliced 1202-02-01 to 1203-01-17
#    fixed time
#    fixed CICE grid
# sliced 1203-02-01 to 1204-01-17
#    fixed time
#    fixed CICE grid
# sliced 1204-02-01 to 1205-01-17
#    fixed time
#    fixed CICE grid
# sliced 1205-02-01 to 1206-01-17
#    fixed time
#    fixed CICE grid
# sliced 1206-02-01 to 1207-01-17
#    fixed time
#    fixed CICE grid
# sliced 1207-02-01 to 1208-01-17
#    fixed time
#    fixed CICE grid
# sliced 1208-02-01 to 1209-01-17
#    fixed time
#    fixed CICE grid
# sliced 1209-02-01 to 1210-01-17
#    fixed time
#    fixed CICE grid
# sliced 1210-02-01 to 1211-01-17
#    fixed time
#    fixed CICE grid
# computed list
# concatenated data
# wrote data to disk
# CPU times: user 21.5 s, sys: 3.69 s, total: 25.1 s
# Wall time: 4min 17s

# %%
# %%time
if var != 'RESTOM' and vert_lev[comp][var_ind]:
    filepath = path_to_arch+cesm2piC+'/'+comp+'/proc/tseries/'
    addon = 'Kayetal22/' if lessmelt else time_path[comp][freq]+'/'
    filepath = filepath+addon
    
    num = 0
    slice_list = []
    for startyr in startyrs:
        yr_range = np.array([str(i).zfill(4) for i in np.arange(startyr,startyr+75)])
        
        endyr = startyr+49
        start_floor = np.floor_divide(startyr,100)
        end_floor = np.floor_divide(endyr,100)
        
        if start_floor == end_floor:
            if start_floor == 0:
                instart = str(1).zfill(4)
                inend = str(99).zfill(4)
            elif start_floor == 19:
                instart = str(1900).zfill(4)
                inend = str(2000).zfill(4)
            else:
                instart = str(start_floor*100).zfill(4)
                inend = str(start_floor*100+99).zfill(4)
        
            yr_extn = {'in': ["."+instart+"01-"+inend+"12.", ".05000101-05991231."],
                       'out': ["."+str(startyr).zfill(4)+"01-"+str(endyr).zfill(4)+"12.", ".05010101-05741231."]}

            
            # Open dataset
            filename = cesm2piC+'.'+mod_com[comp]+h_ext[comp][freq]+var+yr_extn['in'][freq]+'nc'
            print(filepath+filename)
            ds = xr.open_dataset(filepath+filename,chunks=chunks[comp])
        else:
            if start_floor == 0:
                instart1 = str(1).zfill(4)
                inend1 = str(99).zfill(4)
            else:
                instart1 = str(start_floor*100).zfill(4)
                inend1 = str(start_floor*100+99).zfill(4)
                
            if end_floor == 19:
                instart2 = str(1900).zfill(4)
                inend2 = str(2000).zfill(4)
            else:
                instart2 = str(end_floor*100).zfill(4)
                inend2 = str(end_floor*100+99).zfill(4)
    
            yr_extn1 = {'in': ["."+instart1+"01-"+inend1+"12.", ".05000101-05991231."],
                       'out': ["."+str(startyr).zfill(4)+"01-"+str(endyr).zfill(4)+"12.", ".05010101-05741231."]}
    
            yr_extn2 = {'in': ["."+instart2+"01-"+inend2+"12.", ".05000101-05991231."],
                       'out': ["."+str(startyr).zfill(4)+"01-"+str(endyr).zfill(4)+"12.", ".05010101-05741231."]}
            yr_extn = {'out': ["."+str(startyr).zfill(4)+"01-"+str(endyr).zfill(4)+"12.", ".05010101-05741231."]}

            # Open dataset
            filename1 = cesm2piC+'.'+mod_com[comp]+h_ext[comp][freq]+var+yr_extn1['in'][freq]+'nc'
            filename2 = cesm2piC+'.'+mod_com[comp]+h_ext[comp][freq]+var+yr_extn2['in'][freq]+'nc'
            print(filepath+filename1)
            print(filepath+filename2)
            ds = xr.open_mfdataset([filepath+filename1, filepath+filename2],chunks=chunks[comp])
        
        
        add_cyclic = False
        
        dsv = ds
        if start_floor == end_floor:
            filename = cesm2piC+'.'+mod_com[comp]+h_ext[comp][freq]+'PS'+yr_extn['in'][freq]+'nc'
            dsp = xr.open_dataset(filepath+filename,chunks=chunks[comp])
        else:
            filename1 = cesm2piC+'.'+mod_com[comp]+h_ext[comp][freq]+'PS'+yr_extn1['in'][freq]+'nc'
            filename2 = cesm2piC+'.'+mod_com[comp]+h_ext[comp][freq]+'PS'+yr_extn2['in'][freq]+'nc'
            dsp = xr.open_mfdataset([filepath+filename1, filepath+filename2],chunks=chunks[comp])
            
        dsv['PS'] = dsp['PS']
        #del ds
        
        processed_list = []
        for i in range(0,len(yr_range)-1):
            # Selection of final time
                
            # Selection of data    
            startyr_sl = yr_range[i]
            endyr_sl = yr_range[i+1]
            ann_slice = dsv.sel(time=slice(startyr_sl+'-02-01',endyr_sl+'-01-17')) #if add_cyclic else dsv.sel(time=slice(startyr+'-02-10',endyr+'-01-17'),lat=slice(0,90))
            print('sliced '+startyr_sl+'-02-01 to '+endyr_sl+'-01-17')
            
            ann_slice = FixTime(ann_slice)
            print('   fixed time')

            ann_slice = FixLongitude(ann_slice, add_cyclic)
            print('   fixed longitude')
            
            ann_slice = InterPlevels(ann_slice, var)
            print('   interpolated p-levels')
            processed_list.append(ann_slice)

        
        processed_out = xr.concat(processed_list,dim='time').chunk({'time':111})
        slice_list.append(processed_out)  
        print('concatenated slice '+str(num))
        num = num+1
        
    for i in range(0,len(slice_list)):
        if i == 0:
            slice_list[i].to_zarr(path_to_outdata+cesm2piC+h_ext[comp][freq]+var+'.195001-202312.zarr', 
                            group=var)
            print('saved initial zarr store')
        else:
            print('saving slice '+str(i+1))
            slice_list[i].to_zarr(path_to_outdata+cesm2piC+h_ext[comp][freq]+var+'.195001-202312.zarr', 
                                    append_dim='slice', mode='a-',group=var)
    print('wrote data to disk')
# Out:
# CPU times: user 9 µs, sys: 0 ns, total: 9 µs
# Wall time: 11.2 µs

# %%
# %%time

if var == 'RESTOM':
    filepath = path_to_arch+cesm2piC+'/'+comp+'/proc/tseries/'
    addon = 'Kayetal22/' if lessmelt else time_path[comp][freq]+'/'
    filepath = filepath+addon
    
    num = 0
    for startyr in startyrs:
        yr_range = np.array([str(i).zfill(4) for i in np.arange(startyr,startyr+51)])
        
        endyr = startyr+49
        start_floor = np.floor_divide(startyr,100)
        end_floor = np.floor_divide(endyr,100)
        
        if start_floor == end_floor:
            if start_floor == 0:
                instart = str(1).zfill(4)
                inend = str(99).zfill(4)
            elif start_floor == 19:
                instart = str(1900).zfill(4)
                inend = str(2000).zfill(4)
            else:
                instart = str(start_floor*100).zfill(4)
                inend = str(start_floor*100+99).zfill(4)
        
            yr_extn = {'in': ["."+instart+"01-"+inend+"12.", ".05000101-05991231."],
                       'out': ["."+str(startyr).zfill(4)+"01-"+str(endyr).zfill(4)+"12.", ".05010101-05741231."]}
        
            # Open dataset
            filename_fsnt = cesm2piC+'.'+mod_com[comp]+h_ext[comp][freq]+'FSNT'+yr_extn['in'][freq]+'nc'
            filename_flnt = cesm2piC+'.'+mod_com[comp]+h_ext[comp][freq]+'FLNT'+yr_extn['in'][freq]+'nc'
            print(filepath+filename_fsnt)
            ds_fsnt = dask.delayed(xr.open_dataset)(filepath+filename_fsnt,chunks=chunks[comp])
            ds_flnt = dask.delayed(xr.open_dataset)(filepath+filename_flnt,chunks=chunks[comp])

            ds_fsnt = ds_fsnt['FSNT']
            ds_flnt = ds_flnt['FLNT']

            dsv = ds_fsnt-ds_flnt
            dsv = dsv.rename(var) 
            
        else:
            if start_floor == 0:
                instart1 = str(1).zfill(4)
                inend1 = str(99).zfill(4)
            else:
                instart1 = str(start_floor*100).zfill(4)
                inend1 = str(start_floor*100+99).zfill(4)
                
            if end_floor == 19:
                instart2 = str(1900).zfill(4)
                inend2 = str(2000).zfill(4)
            else:
                instart2 = str(end_floor*100).zfill(4)
                inend2 = str(end_floor*100+99).zfill(4)
    
            yr_extn1 = {'in': ["."+instart1+"01-"+inend1+"12.", ".05000101-05991231."],
                       'out': ["."+str(startyr).zfill(4)+"01-"+str(endyr).zfill(4)+"12.", ".05010101-05741231."]}
    
            yr_extn2 = {'in': ["."+instart2+"01-"+inend2+"12.", ".05000101-05991231."],
                       'out': ["."+str(startyr).zfill(4)+"01-"+str(endyr).zfill(4)+"12.", ".05010101-05741231."]}
            yr_extn = {'out': ["."+str(startyr).zfill(4)+"01-"+str(endyr).zfill(4)+"12.", ".05010101-05741231."]}
    
            # Open dataset
            filename1_fsnt = cesm2piC+'.'+mod_com[comp]+h_ext[comp][freq]+'FSNT'+yr_extn1['in'][freq]+'nc'
            filename2_fsnt = cesm2piC+'.'+mod_com[comp]+h_ext[comp][freq]+'FSNT'+yr_extn2['in'][freq]+'nc'

            filename1_flnt = cesm2piC+'.'+mod_com[comp]+h_ext[comp][freq]+'FLNT'+yr_extn1['in'][freq]+'nc'
            filename2_flnt = cesm2piC+'.'+mod_com[comp]+h_ext[comp][freq]+'FLNT'+yr_extn2['in'][freq]+'nc'
            
            print(filepath+filename1_fsnt)
            print(filepath+filename2_fsnt)
            ds_fsnt = dask.delayed(xr.open_mfdataset)([filepath+filename1_fsnt, filepath+filename2_fsnt],chunks=chunks[comp])
            ds_flnt = dask.delayed(xr.open_mfdataset)([filepath+filename1_flnt, filepath+filename2_flnt],chunks=chunks[comp])

            ds_fsnt = ds_fsnt['FSNT']
            ds_flnt = ds_flnt['FLNT']

            dsv = ds_fsnt-ds_flnt
            dsv = dsv.rename(var)
        
        add_cyclic = False
        
        #del ds
        
        processed_list = []
        for i in range(0,len(yr_range)-1):
            # If monthly data
            if freq == 0:
                startyr = yr_range[i]
                endyr = yr_range[i+1]
                ann_slice = dsv.sel(time=slice(startyr+'-02-01',endyr+'-01-17')) #if add_cyclic else dsv.sel(time=slice(startyr+'-02-10',endyr+'-01-17'),lat=slice(0,90))
                print('sliced '+startyr+'-02-01 to '+endyr+'-01-17')
                
                fixedtime_data = dask.delayed(FixTime)(ann_slice)
                print('   fixed time')
        
                if comp == 'ice':
                    fixedgrid_data = dask.delayed(FixGrid)(fixedtime_data,'gx1v7')
                    processed_list.append(fixedgrid_data)
                    print('   fixed CICE grid')
        
                    #del ann_slice, fixedtime_data, fixedgrid_data
                elif comp == 'ocn':
                    processed_list.append(fixedtime_data)
        
                    #del ann_slice, fixedtime_data
                else:
                    fixedgrid_data = dask.delayed(FixLongitude)(fixedtime_data, add_cyclic)
                    # If 3D data, interpolate to pressure levels
                    if vert_lev[comp][var_ind]:
                        addplev_data = dask.delayed(InterPlevels)(fixedgrid_data, var)
                        processed_list.append(addplev_data)
                    else:
                        processed_list.append(fixedgrid_data)
                    print('   fixed longitude')
        
                    #del ann_slice, fixedtime_data, fixedgrid_data
                    
                
            # If daily data
            else:
                startyr = yr_range[i]
                endyr = yr_range[i]
                ann_slice = dsv.sel(time=slice(startyr+'-01-01',endyr+'-12-31')) #if add_cyclic else dsv.sel(time=slice(startyr+'-01-01',endyr+'-12-31'), lat=slice(0,90))
                print('sliced '+startyr+'-01-01 to '+endyr+'-12-31')
        
                if comp == 'ice':
                    fixedgrid_data = dask.delayed(FixGrid)(ann_slice,'gx1v7')
                    processed_list.append(fixedgrid_data)
                    print('   fixed CICE grid')
        
                    #del ann_slice, fixedgrid_data
                elif comp == 'ocn':
                    processed_list.append(ann_slice)
        
                    #del ann_slice
                else:
                    fixedgrid_data = dask.delayed(FixLongitude)(ann_slice, add_cyclic)
                    processed_list.append(fixedgrid_data)
                    print('   fixed longitude')
        
                    #del ann_slice, fixedgrid_data
        
        processed_comp = dask.compute(*processed_list)
        print('computed list')
        
        if not vert_lev[comp][var_ind] and freq == 0:
            processed_out = xr.concat(processed_comp,dim='time').chunk({'time':111})
            print('concatenated data')
            
            processed_out.to_netcdf(path_to_outdata+cesm2piC+h_ext[comp][freq]+var+yr_extn['out'][freq]+'nc', 
                                        format='NETCDF4',encoding={var: {"zlib": True, "complevel": 1}})
            print('wrote data to disk')
            
        else:
            processed_comp[0].to_zarr(path_to_outdata+cesm2piC+h_ext[comp][freq]+var+yr_extn['out'][freq]+'zarr', 
                                    group=var)
            print('saved initial zarr store')
            for i in range(1,len(processed_comp)):
                print('   saving year '+str(i+500))
                processed_comp[i].to_zarr(path_to_outdata+cesm2piC+h_ext[comp][freq]+var+yr_extn['out'][freq]+'zarr', 
                                    append_dim='time', mode='a-',group=var)
            print('wrote data to disk')
    
        num = num+1
# Out:
# CPU times: user 5 µs, sys: 0 ns, total: 5 µs
# Wall time: 6.68 µs

# %%
client.shutdown()
