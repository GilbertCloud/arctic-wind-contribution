# %% [markdown]
# # Processing PiC_UVnudge single run data

# %% [markdown]
# ### Set up
# #### Packages

# %%
import numpy as np
import xarray as xr
import pandas as pd
from scipy import stats
import warnings
warnings.filterwarnings('ignore')
import datetime as dt
from datetime import timedelta
from Processing_functions import FixLongitude, FixTime, FixGrid, InterPlevels
xr.set_options(display_expand_data=False);
xr.set_options(keep_attrs=True);
import dask
from dask_jobqueue import PBSCluster
from dask.distributed import Client
from dask.diagnostics import ProgressBar

# %% [markdown]
# #### Filepaths & name variables

# %%
## Test numbers
#tst_nums = np.arange(1,4)

## File name
run_name = 'PiC_UVnudge_1988'
piC_UVnudge_name = 'b.e21.B1850cmip6.f09_g17.'+run_name

## Filepaths
path_to_arch = "/glade/derecho/scratch/glydia/archive/"
comp = 'atm'
freq = 0 # 0: monthly, 1: daily
var_ind = -1

# Variables
var_list = {'atm': ['TS','FLDS','CLOUD','FLNS','FSNS','FLNT','FSNT','PSL','U','V','T','TREFHT',
                    'Target_U','Target_V','Target_T','RESTOM','Z3'],
            'ice': ['aice','hi'],
            'ocn': ['MOC']}
var_ext = {0: '', 1: '_d'}
var = var_list[comp][var_ind]+var_ext[freq]

# Extensions
h_ext = {'atm': ['.h0.'],
       'ice': ['.h.','.h1.'],
       'ocn': ['.h.']}
mod_com = {'atm': 'cam',
           'ice': 'cice',
           'ocn': 'pop'}
time_path = {'atm': ['month_1'],
                'ice': ['month_1','day_1'],
                'ocn': ['month_1']}
yr_extn = {'in': [".195001-202312.", ".*0101-*1231."],
           'out': [".195001-202312.", ".19500101-20231231."]}
vert_lev = {'atm': [False,False,True,False,False,False,False,False,True,True,True,
                    False,True,True,True,False,True],
            'ice': [False,False],
            'ocn': [False]}

path_to_outdata = '/glade/work/glydia/Arctic_controls_processed_data/processed_'+run_name+'_data/'

# %%
cluster = PBSCluster(cores    = 1,
                     memory   = '25GiB',
                     queue    = 'casper',
                     walltime = '02:00:00',
                     project  = 'UCUB0137',
                     name='piControl_'+var)
cluster.scale(4*9)
client = Client(cluster)

# %%
client
# Out:
# <Client: 'tcp://128.117.208.97:36183' processes=0 threads=0, memory=0 B>

# %%
## Chunking variables
time_ch = 365*2 if freq == 1 else 600
chunks = {
    'atm': {'time': time_ch, 'lat': 96, 'lon': 144, 'lev': -1},
    'ice': {'time': time_ch, 'nj': 192, 'ni': 160},
    'ocn': {'time': time_ch, 'nlat': 64, 'nlon': 96, 'z_t': 5}
}

# %% [markdown]
# ### Load & modify data
# #### Control data

# %%
# %%time

yr_range = np.array([str(i).zfill(4) for i in np.arange(1950,2025)])

tst_name = piC_UVnudge_name+'.001'
## Load data
# Open dataset
filepath = path_to_arch+tst_name+'/'+comp+'/proc/tseries/'+time_path[comp][freq]+'/'
filename = tst_name+h_ext[comp][freq]+var+yr_extn['in'][freq]+'nc'
print(filepath+filename)
if freq == 0:
    ds = dask.delayed(xr.open_dataset)(filepath+filename,chunks=chunks[comp])
else:
    ds = xr.open_mfdataset(paths=filepath+filename,chunks=chunks[comp],parallel=True)

add_cyclic = False # DO NOT ADD CYCLIC UNTIL AFTER PROCESSING PLOT DATA

dsv = ds[var] if add_cyclic else ds

#del ds

processed_list = []
for j in range(0,len(yr_range)-1):
    # If monthly data
    if freq == 0:
        startyr = yr_range[j]
        endyr = yr_range[j+1]
        ann_slice = dsv.sel(time=slice(startyr+'-02-01',endyr+'-01-17')) #if add_cyclic else dsv.sel(time=slice(startyr+'-02-10',endyr+'-01-17'),lat=slice(0,90))
        print('sliced '+startyr+'-02-01 to '+endyr+'-01-17')
        
        fixedtime_data = dask.delayed(FixTime)(ann_slice)
        print('   fixed time')

        if comp == 'ice':
            fixedgrid_data = dask.delayed(FixGrid)(fixedtime_data,'gx1v7')
            processed_list.append(fixedgrid_data)
            print('   fixed CICE grid')

            #del ann_slice, fixedtime_data, fixedgrid_data
        elif comp == 'ocn':
            processed_list.append(fixedtime_data)

            #del ann_slice, fixedtime_data
        else:
            fixedgrid_data = dask.delayed(FixLongitude)(fixedtime_data, add_cyclic)
            # If 3D data, interpolate to pressure levels
            if vert_lev[comp][var_ind]:
                addplev_data = dask.delayed(InterPlevels)(fixedgrid_data, var)
                processed_list.append(addplev_data)
            else:
                processed_list.append(fixedgrid_data)
            print('   fixed longitude')

            #del ann_slice, fixedtime_data, fixedgrid_data
            
        
    # If daily data
    else:
        startyr = yr_range[j]
        endyr = yr_range[j]
        ann_slice = dsv.sel(time=slice(startyr+'-01-01',endyr+'-12-31')) #if add_cyclic else dsv.sel(time=slice(startyr+'-01-01',endyr+'-12-31'), lat=slice(0,90))
        print('sliced '+startyr+'-01-01 to '+endyr+'-12-31')

        if comp == 'ice':
            fixedgrid_data = dask.delayed(FixGrid)(ann_slice,'gx1v7')
            processed_list.append(fixedgrid_data)
            print('   fixed CICE grid')

            #del ann_slice, fixedgrid_data
        elif comp == 'ocn':
            processed_list.append(ann_slice)

            #del ann_slice
        else:
            fixedgrid_data = dask.delayed(FixLongitude)(ann_slice, add_cyclic)
            processed_list.append(fixedgrid_data)
            print('   fixed longitude')

if add_cyclic and freq == 0:
    processed_comp = dask.compute(*processed_list)
    print('computed list')
    
    processed_out = xr.concat(processed_comp,dim='time').chunk({'time':111})
    print('concatenated data')
    
    processed_out.to_netcdf(path_to_outdata+piC_UVnudge_name+h_ext[comp][freq]+var+yr_extn['out'][freq]+'nc', 
                                format='NETCDF4',encoding={var: {"zlib": True, "complevel": 1}})
    print('wrote data to disk')
    
else:
    processed_comp = dask.compute(*processed_list)
    processed_comp[0].to_zarr(path_to_outdata+piC_UVnudge_name+h_ext[comp][freq]+var+yr_extn['out'][freq]+'zarr', 
                            group=var)
    print('saved initial zarr store')
    for i in range(1,len(yr_range)-1):
        yr = str(yr_range[i])
        print('   saving year '+yr)
        
        processed_comp[i].sel(time=slice(yr+'-01-01',yr+'-12-31')).to_zarr(path_to_outdata+piC_UVnudge_name+h_ext[comp][freq]+var+yr_extn['out'][freq]+'zarr', 
                            append_dim='time', mode='a-',group=var)
    print('wrote data to disk')
# Out:
# /glade/derecho/scratch/glydia/archive/b.e21.B1850cmip6.f09_g17.PiC_UVnudgenew.001/atm/proc/tseries/month_1/b.e21.B1850cmip6.f09_g17.PiC_UVnudgenew.001.h0.Z3.195001-202312.nc
# sliced 1950-02-01 to 1951-01-17
#    fixed time
#    fixed longitude
# sliced 1951-02-01 to 1952-01-17
#    fixed time
#    fixed longitude
# sliced 1952-02-01 to 1953-01-17
#    fixed time
#    fixed longitude
# sliced 1953-02-01 to 1954-01-17
#    fixed time
#    fixed longitude
# sliced 1954-02-01 to 1955-01-17
#    fixed time
#    fixed longitude
# sliced 1955-02-01 to 1956-01-17
#    fixed time
#    fixed longitude
# sliced 1956-02-01 to 1957-01-17
#    fixed time
#    fixed longitude
# sliced 1957-02-01 to 1958-01-17
#    fixed time
#    fixed longitude
# sliced 1958-02-01 to 1959-01-17
#    fixed time
#    fixed longitude
# sliced 1959-02-01 to 1960-01-17
#    fixed time
#    fixed longitude
# sliced 1960-02-01 to 1961-01-17
#    fixed time
#    fixed longitude
# sliced 1961-02-01 to 1962-01-17
#    fixed time
#    fixed longitude
# sliced 1962-02-01 to 1963-01-17
#    fixed time
#    fixed longitude
# sliced 1963-02-01 to 1964-01-17
#    fixed time
#    fixed longitude
# sliced 1964-02-01 to 1965-01-17
#    fixed time
#    fixed longitude
# sliced 1965-02-01 to 1966-01-17
#    fixed time
#    fixed longitude
# sliced 1966-02-01 to 1967-01-17
#    fixed time
#    fixed longitude
# sliced 1967-02-01 to 1968-01-17
#    fixed time
#    fixed longitude
# sliced 1968-02-01 to 1969-01-17
#    fixed time
#    fixed longitude
# sliced 1969-02-01 to 1970-01-17
#    fixed time
#    fixed longitude
# sliced 1970-02-01 to 1971-01-17
#    fixed time
#    fixed longitude
# sliced 1971-02-01 to 1972-01-17
#    fixed time
#    fixed longitude
# sliced 1972-02-01 to 1973-01-17
#    fixed time
#    fixed longitude
# sliced 1973-02-01 to 1974-01-17
#    fixed time
#    fixed longitude
# sliced 1974-02-01 to 1975-01-17
#    fixed time
#    fixed longitude
# sliced 1975-02-01 to 1976-01-17
#    fixed time
#    fixed longitude
# sliced 1976-02-01 to 1977-01-17
#    fixed time
#    fixed longitude
# sliced 1977-02-01 to 1978-01-17
#    fixed time
#    fixed longitude
# sliced 1978-02-01 to 1979-01-17
#    fixed time
#    fixed longitude
# sliced 1979-02-01 to 1980-01-17
#    fixed time
#    fixed longitude
# sliced 1980-02-01 to 1981-01-17
#    fixed time
#    fixed longitude
# sliced 1981-02-01 to 1982-01-17
#    fixed time
#    fixed longitude
# sliced 1982-02-01 to 1983-01-17
#    fixed time
#    fixed longitude
# sliced 1983-02-01 to 1984-01-17
#    fixed time
#    fixed longitude
# sliced 1984-02-01 to 1985-01-17
#    fixed time
#    fixed longitude
# sliced 1985-02-01 to 1986-01-17
#    fixed time
#    fixed longitude
# sliced 1986-02-01 to 1987-01-17
#    fixed time
#    fixed longitude
# sliced 1987-02-01 to 1988-01-17
#    fixed time
#    fixed longitude
# sliced 1988-02-01 to 1989-01-17
#    fixed time
#    fixed longitude
# sliced 1989-02-01 to 1990-01-17
#    fixed time
#    fixed longitude
# sliced 1990-02-01 to 1991-01-17
#    fixed time
#    fixed longitude
# sliced 1991-02-01 to 1992-01-17
#    fixed time
#    fixed longitude
# sliced 1992-02-01 to 1993-01-17
#    fixed time
#    fixed longitude
# sliced 1993-02-01 to 1994-01-17
#    fixed time
#    fixed longitude
# sliced 1994-02-01 to 1995-01-17
#    fixed time
#    fixed longitude
# sliced 1995-02-01 to 1996-01-17
#    fixed time
#    fixed longitude
# sliced 1996-02-01 to 1997-01-17
#    fixed time
#    fixed longitude
# sliced 1997-02-01 to 1998-01-17
#    fixed time
#    fixed longitude
# sliced 1998-02-01 to 1999-01-17
#    fixed time
#    fixed longitude
# sliced 1999-02-01 to 2000-01-17
#    fixed time
#    fixed longitude
# sliced 2000-02-01 to 2001-01-17
#    fixed time
#    fixed longitude
# sliced 2001-02-01 to 2002-01-17
#    fixed time
#    fixed longitude
# sliced 2002-02-01 to 2003-01-17
#    fixed time
#    fixed longitude
# sliced 2003-02-01 to 2004-01-17
#    fixed time
#    fixed longitude
# sliced 2004-02-01 to 2005-01-17
#    fixed time
#    fixed longitude
# sliced 2005-02-01 to 2006-01-17
#    fixed time
#    fixed longitude
# sliced 2006-02-01 to 2007-01-17
#    fixed time
#    fixed longitude
# sliced 2007-02-01 to 2008-01-17
#    fixed time
#    fixed longitude
# sliced 2008-02-01 to 2009-01-17
#    fixed time
#    fixed longitude
# sliced 2009-02-01 to 2010-01-17
#    fixed time
#    fixed longitude
# sliced 2010-02-01 to 2011-01-17
#    fixed time
#    fixed longitude
# sliced 2011-02-01 to 2012-01-17
#    fixed time
#    fixed longitude
# sliced 2012-02-01 to 2013-01-17
#    fixed time
#    fixed longitude
# sliced 2013-02-01 to 2014-01-17
#    fixed time
#    fixed longitude
# sliced 2014-02-01 to 2015-01-17
#    fixed time
#    fixed longitude
# sliced 2015-02-01 to 2016-01-17
#    fixed time
#    fixed longitude
# sliced 2016-02-01 to 2017-01-17
#    fixed time
#    fixed longitude
# sliced 2017-02-01 to 2018-01-17
#    fixed time
#    fixed longitude
# sliced 2018-02-01 to 2019-01-17
#    fixed time
#    fixed longitude
# sliced 2019-02-01 to 2020-01-17
#    fixed time
#    fixed longitude
# sliced 2020-02-01 to 2021-01-17
#    fixed time
#    fixed longitude
# sliced 2021-02-01 to 2022-01-17
#    fixed time
#    fixed longitude
# sliced 2022-02-01 to 2023-01-17
#    fixed time
#    fixed longitude
# sliced 2023-02-01 to 2024-01-17
#    fixed time
#    fixed longitude
# saved initial zarr store
#    saving year 1951
#    saving year 1952
#    saving year 1953
#    saving year 1954
#    saving year 1955
#    saving year 1956
#    saving year 1957
#    saving year 1958
#    saving year 1959
#    saving year 1960
#    saving year 1961
#    saving year 1962
#    saving year 1963
#    saving year 1964
#    saving year 1965
#    saving year 1966
#    saving year 1967
#    saving year 1968
#    saving year 1969
#    saving year 1970
#    saving year 1971
#    saving year 1972
#    saving year 1973
#    saving year 1974
#    saving year 1975
#    saving year 1976
#    saving year 1977
#    saving year 1978
#    saving year 1979
#    saving year 1980
#    saving year 1981
#    saving year 1982
#    saving year 1983
#    saving year 1984
#    saving year 1985
#    saving year 1986
#    saving year 1987
#    saving year 1988
#    saving year 1989
#    saving year 1990
#    saving year 1991
#    saving year 1992
#    saving year 1993
#    saving year 1994
#    saving year 1995
#    saving year 1996
#    saving year 1997
#    saving year 1998
#    saving year 1999
#    saving year 2000
#    saving year 2001
#    saving year 2002
#    saving year 2003
#    saving year 2004
#    saving year 2005
#    saving year 2006
#    saving year 2007
#    saving year 2008
#    saving year 2009
#    saving year 2010
#    saving year 2011
#    saving year 2012
#    saving year 2013
#    saving year 2014
#    saving year 2015
#    saving year 2016
#    saving year 2017
#    saving year 2018
#    saving year 2019
#    saving year 2020
#    saving year 2021
#    saving year 2022
#    saving year 2023
# wrote data to disk
# CPU times: user 11.7 s, sys: 2.04 s, total: 13.7 s
# Wall time: 4min 22s

# %%
client.shutdown()
